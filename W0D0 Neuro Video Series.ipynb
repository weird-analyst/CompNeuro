# %% [markdown]
# # Lecture 1: Intro to Brain Science

# %% [markdown]
# Brain and Mind
#
# Mind == Ideas and purposes, ability of an object to find invariances and spot regularities, it works on algorithms and instruction sets
#
# Brain == Material Stuff and Processes, has it's own physiology and chemistry. Has its own dynamics which gives rise to mind!
#
# How come the dynamics of this material object gives rise to  mind? A very complex question that we are trying to answer
#
# About 20% of bodies oxygen is consumed in the brain, which is a lot.
#
# Neocortex (outer layer of cerebrum) of the brain:
# ![image.png](attachment:image.png)
#
# Subcortical Regions:
# ![image-2.png](attachment:image-2.png)
#
# We know various data about the brain the electric impulses while it does certain things, the areas that get activated while something happens, we want to coorelate that and find out how the brain works and make a replica if possible.
#
# In computational neuroscience we will see everything that a human body does, all the information that's avalaible to us and coorelate that to how the brain could work!

# %% [markdown]
# Hardware of the Brain: Neurons
#
# Neurons are very specialised cells
# ![image.png](attachment:image.png)
#
# Action potentials are the way neurons communicate with each other. An Action Potential is the currency of information processing in the brain.
